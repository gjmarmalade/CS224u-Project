# %% [markdown]
# **Decoder**
# &emsp;1. RNN decoder
# &emsp;2. Transformer decoder
# &emsp;3. pointer network decoder
# &emsp;4. ...

# %%
class Decoder(nn.Module):  # class name should be changed according to different variants
  def __init__(params):
    pass
  
  def forward(self, embedded_inputs):
    pass

# %%
class Decoder(nn.Module):  # class name should be changed according to different variants
  def __init__(params):
    pass
  
  def forward(self, embedded_inputs):
    pass

# %%
class Decoder(nn.Module):  # class name should be changed according to different variants
  def __init__(params):
    pass
  
  def forward(self, embedded_inputs):
    pass
