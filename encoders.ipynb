# %% [markdown]
# **Encoder1/Encoder2**
# &emsp;1. RNN encoder
# &emsp;2. Transformer encoder
# &emsp;3. pointer network encoder
# &emsp;4. ...

# %%
class Encoder(nn.Module):  # class name should be changed according to different variants
  def __init__(params):
    pass
  
  def forward(self, embedded_inputs):
    pass

# %%
class Encoder(nn.Module):  # class name should be changed according to different variants
  def __init__(params):
    pass
  
  def forward(self, embedded_inputs):
    pass

# %%
class Encoder(nn.Module):  # class name should be changed according to different variants
  def __init__(params):
    pass
  
  def forward(self, embedded_inputs):
    pass
