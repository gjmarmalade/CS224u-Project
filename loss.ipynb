# %%
class ReconLoss(nn.Module):
  def __init__(params):
    pass
  
  def forward(self, embedded_inputs):
    pass

# %%
class DiscriminatorLoss(nn.Module):
  def __init__(params):
    pass
  
  def forward(self, embedded_inputs):
    pass
